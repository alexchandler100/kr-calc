# %%
import os
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
pd.set_option('display.max_rows', 1000)
os.chdir('/Users/alexchandler/kr-calc/csv_files') #change to python script directory
complete_knot_info = pd.read_csv('knotinfo_data_complete.csv', dtype='object') 
import matplotlib as plt
import matplotlib.image as mpimg


import sklearn
import scipy
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import VarianceThreshold
import itertools


# import required module for iterating through directory
import os
import json
# assign directory
os.chdir('/Users/alexchandler/kr-calc') #change to python script directory
directory = 'data'
#we create a dictionary with keys: names of knots
                          #values: dictionaries (keys: nonzero gradings, values: homology dimensions)
homfly_data={}
# sort directory and then iterate over files in that directory, creating a dictionary for easier use
listing = os.listdir(directory)
listing.sort()
for filename in listing:
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        with open(f) as json_file:
            data = json.load(json_file)
            data_dict = {}
            for i in range(int(len(data)/2)):
                data_dict[tuple(data[2*i])]=data[2*i+1]
            homfly_data[filename[:-5]]=data_dict
            
#import functions from functions.py (contains all functions being called in this notebook)
os.chdir('/Users/alexchandler/kr-calc/python_scripts') #change to python script directory
from functions import *

# %%
complete_knot_info
# Out:
#          name                    name_anon         diagram  \
# 0        Name                          NaN         Diagram
# 1         0_1       diagram_display.php?_1      0_1-50.png
# 2         3_1      diagram_display.php?3_1      3_1-50.png
# 3         4_1      diagram_display.php?4_1      4_1-50.png
# 4         5_1      diagram_display.php?5_1      5_1-50.png
# ...       ...                          ...             ...
# 2974  12n_884  diagram_display.php?12n_884  12n_884-50.png
# 2975  12n_885  diagram_display.php?12n_885  12n_885-50.png
# 2976  12n_886  diagram_display.php?12n_886  12n_886-50.png
# 2977  12n_887  diagram_display.php?12n_887  12n_887-50.png
# 2978  12n_888  diagram_display.php?12n_888  12n_888-50.png
#
#                      diagram_anon  category category_anon       knot_atlas  \
# 0                             NaN  Category           NaN  Knot Atlas Page
# 1          diagram_display.php?_1         0           NaN              0.1
# 2         diagram_display.php?3_1         3           NaN              3.1
# 3         diagram_display.php?4_1         4           NaN              4.1
# 4         diagram_display.php?5_1         5           NaN              5.1
# ...                           ...       ...           ...              ...
# 2974  diagram_display.php?12n_884       12n           NaN              NaN
# 2975  diagram_display.php?12n_885       12n           NaN              NaN
# 2976  diagram_display.php?12n_886       12n           NaN              NaN
# 2977  diagram_display.php?12n_887       12n           NaN              NaN
# 2978  diagram_display.php?12n_888       12n           NaN              NaN
#
#                               knot_atlas_anon  knotilus_page  \
# 0                                         NaN  Knotilus Page
# 1     http://katlas.math.toronto.edu/wiki/0_1            NaN
# 2     http://katlas.math.toronto.edu/wiki/3_1             Go
# 3     http://katlas.math.toronto.edu/wiki/4_1             Go
# 4     http://katlas.math.toronto.edu/wiki/5_1             Go
# ...                                       ...            ...
# 2974                                      NaN             Go
# 2975                                      NaN             Go
# 2976                                      NaN             Go
# 2977                                      NaN             Go
# 2978                                      NaN             Go
#
#                                      knotilus_page_anon  ...  adequate  \
# 0                                                   NaN  ...  Adequate
# 1                                                   NaN  ...         Y
# 2     http://srankin.math.uwo.ca/cgi-bin/retrieve.cg...  ...         Y
# 3     http://srankin.math.uwo.ca/cgi-bin/retrieve.cg...  ...         Y
# 4     http://srankin.math.uwo.ca/cgi-bin/retrieve.cg...  ...         Y
# ...                                                 ...  ...       ...
# 2974  http://srankin.math.uwo.ca/cgi-bin/retrieve.cg...  ...       NaN
# 2975  http://srankin.math.uwo.ca/cgi-bin/retrieve.cg...  ...       NaN
# 2976  http://srankin.math.uwo.ca/cgi-bin/retrieve.cg...  ...       NaN
# 2977  http://srankin.math.uwo.ca/cgi-bin/retrieve.cg...  ...       NaN
# 2978  http://srankin.math.uwo.ca/cgi-bin/retrieve.cg...  ...       NaN
#
#           adequate_anon  montesinos_notation montesinos_notation_anon  \
# 0     Adequate Citation  Montesinos Notation                      NaN
# 1                   NaN                  NaN                      NaN
# 2                   NaN               K(1/3)                      NaN
# 3                   NaN               K(2/5)                      NaN
# 4                   NaN               K(1/5)                      NaN
# ...                 ...                  ...                      ...
# 2974                NaN       Not Montesinos                      NaN
# 2975                NaN       Not Montesinos                      NaN
# 2976                NaN       Not Montesinos                      NaN
# 2977                NaN       Not Montesinos                      NaN
# 2978                NaN       Not Montesinos                      NaN
#
#       boundary_slopes boundary_slopes_anon   pretzel_notation  \
# 0     Boundary Slopes                  NaN   Pretzel Notation
# 1                 NaN                  NaN               P(1)
# 2              {0,6}                   NaN        P(-1,-1,-1)
# 3           {-4,0,4}                   NaN           P(1,1,2)
# 4             {0,10}                   NaN  P(-1,-1,-1,-1,-1)
# ...               ...                  ...                ...
# 2974              NaN                  NaN                NaN
# 2975              NaN                  NaN                NaN
# 2976              NaN                  NaN                NaN
# 2977              NaN                  NaN                NaN
# 2978              NaN                  NaN                NaN
#
#      pretzel_notation_anon  double_slice_genus double_slice_genus_anon
# 0                      NaN  Double Slice Genus                     NaN
# 1                      NaN                 NaN                     NaN
# 2                      NaN                   2                     NaN
# 3                      NaN                   2                     NaN
# 4                      NaN                   4                     NaN
# ...                    ...                 ...                     ...
# 2974                   NaN                   2                     NaN
# 2975                   NaN                   2                     NaN
# 2976                   NaN                   2                     NaN
# 2977                   NaN                   4                     NaN
# 2978                   NaN                  10                     NaN
#
# [2979 rows x 206 columns]

# %%
knot = complete_knot_info['name'][10]
#configuring the plot
plt.gca().set_aspect('equal', adjustable='box')
img = mpimg.imread('diagrams/'+knot+'.png')
show_knot = plt.imshow(img)
